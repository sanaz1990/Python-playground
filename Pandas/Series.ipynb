# %%
import pandas as pd
pokemon=pd.read_csv("pokemon.csv",usecols=["Pokemon"],squeeze=True)
google=pd.read_csv("google_stock_price.csv", squeeze=True)

# %%
len(pokemon)
# Out:
# 721

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
sorted(google)
# Out:
# [49.95,
#  50.07,
#  50.12,
#  50.7,
#  50.74,
#  50.95,
#  51.1,
#  51.1,
#  51.13,
#  52.38,
#  52.61,
#  52.95,
#  53.02,
#  53.7,
#  53.9,
#  54.1,
#  54.65,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  58.86,
#  59.07,
#  59.13,
#  59.62,
#  59.86,
#  60.35,
#  63.37,
#  64.74,
#  65.47,
#  66.22,
#  67.46,
#  67.56,
#  68.47,
#  68.63,
#  68.8,
#  69.12,
#  69.36,
#  70.17,
#  70.38,
#  70.93,
#  71.98,
#  73.9,
#  74.51,
#  74.62,
#  82.47,
#  83.68,
#  83.69,
#  83.85,
#  84.27,
#  84.59,
#  84.62,
#  84.91,
#  85.14,
#  85.63,
#  85.74,
#  86.13,
#  86.16,
#  86.19,
#  86.19,
#  86.63,
#  87.29,
#  87.41,
#  87.71,
#  88.06,
#  88.15,
#  88.47,
#  88.81,
#  89.21,
#  89.22,
#  89.26,
#  89.4,
#  89.54,
#  89.56,
#  89.61,
#  89.61,
#  89.7,
#  89.8,
#  89.89,
#  89.9,
#  89.93,
#  89.93,
#  89.95,
#  90.11,
#  90.13,
#  90.16,
#  90.27,
#  90.35,
#  90.43,
#  90.58,
#  90.62,
#  90.81,
#  90.9,
#  90.91,
#  91.42,
#  91.78,
#  92.26,
#  92.34,
#  92.41,
#  92.42,
#  92.5,
# ...

# %%
list(google)
# Out:
# [50.12,
#  54.1,
#  54.65,
#  52.38,
#  52.95,
#  53.9,
#  53.02,
#  50.95,
#  51.13,
#  50.07,
#  50.7,
#  49.95,
#  50.74,
#  51.1,
#  51.1,
#  52.61,
#  53.7,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  59.62,
#  58.86,
#  59.13,
#  60.35,
#  59.86,
#  59.07,
#  63.37,
#  65.47,
#  64.74,
#  66.22,
#  67.46,
#  69.12,
#  68.47,
#  69.36,
#  68.8,
#  67.56,
#  68.63,
#  70.38,
#  70.93,
#  71.98,
#  74.51,
#  73.9,
#  70.17,
#  74.62,
#  86.13,
#  93.61,
#  90.81,
#  92.89,
#  96.55,
#  95.22,
#  97.92,
#  97.34,
#  95.74,
#  92.26,
#  84.59,
#  86.19,
#  84.27,
#  83.85,
#  91.42,
#  90.91,
#  92.34,
#  86.19,
#  86.16,
#  83.69,
#  84.62,
#  82.47,
#  83.68,
#  87.29,
#  89.61,
#  90.43,
#  90.9,
#  89.89,
#  89.61,
#  90.11,
#  88.06,
#  85.63,
#  84.91,
#  86.63,
#  85.74,
#  85.14,
#  89.26,
#  89.8,
#  88.15,
#  89.95,
#  92.42,
#  91.78,
#  93.06,
#  93.86,
#  95.86,
#  96.28,
#  96.35,
#  98.7,
#  96.3,
#  101.25,
#  97.15,
#  96.66,
#  94.18,
#  96.83,
#  97.43,
#  96.67,
# ...

# %%
gdata=google.tail(10)
gdata
# Out:
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64
