# %%
import pandas as pd
worldstats=pd.read_csv("worldstats.csv", index_col=["country","year"])
worldstats.head()
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12

# %%
worldstats.stack()
type(worldstats.stack()
)
# Out:
# pandas.core.series.Series

# %%
worldstats=worldstats.stack().to_frame().rename(mapper={0:"Value"}, axis=1)

# %%
worldstats.index.set_names("Col3", level=2, inplace=True)

# %%
worldstats.head()
# Out:
#                                    Value
# country    year Col3
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %%
worldstats.index.get_level_values(2).unique()
# Out:
# Index(['Population', 'GDP'], dtype='object', name='Col3')

# %%
worldstats=worldstats.unstack()
worldstats
# Out:
#                        Value
# Col3              Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
# ...                      ...           ...
# Zimbabwe    2011  14255592.0  1.095623e+10
#             2012  14565482.0  1.239272e+10
#             2013  14898092.0  1.349023e+10
#             2014  15245855.0  1.419691e+10
#             2015  15602751.0  1.389294e+10
#
# [11211 rows x 2 columns]

# %%
worldstats.loc[("Afghanistan")]
# Out:
#            Value
# Col3  Population           GDP
# year
# 1960   8994793.0  5.377778e+08
# 1961   9164945.0  5.488889e+08
# 1962   9343772.0  5.466667e+08
# 1963   9531555.0  7.511112e+08
# 1964   9728645.0  8.000000e+08
# 1965   9935358.0  1.006667e+09
# 1966  10148841.0  1.400000e+09
# 1967  10368600.0  1.673333e+09
# 1968  10599790.0  1.373333e+09
# 1969  10849510.0  1.408889e+09
# 1970  11121097.0  1.748887e+09
# 1971  11412821.0  1.831109e+09
# 1972  11716896.0  1.595555e+09
# 1973  12022514.0  1.733333e+09
# 1974  12315553.0  2.155555e+09
# 1975  12582954.0  2.366667e+09
# 1976  12831361.0  2.555556e+09
# 1977  13056499.0  2.953333e+09
# 1978  13222547.0  3.300000e+09
# 1979  13283279.0  3.697940e+09
# 1980  13211412.0  3.641723e+09
# 1981  12996923.0  3.478788e+09
# 2001  20531160.0  2.461666e+09
# 2002  21487079.0  4.128818e+09
# 2003  22507368.0  4.583649e+09
# 2004  23499850.0  5.285462e+09
# 2005  24399948.0  6.275076e+09
# 2006  25183615.0  7.057598e+09
# ...

# %%
worldstats.unstack()
# Out:
#                            Value                                            \
# Col3                  Population
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
worldstats.loc[("Afghanistan")]
# Out:
#            Value
# Col3  Population           GDP
# year
# 1960   8994793.0  5.377778e+08
# 1961   9164945.0  5.488889e+08
# 1962   9343772.0  5.466667e+08
# 1963   9531555.0  7.511112e+08
# 1964   9728645.0  8.000000e+08
# 1965   9935358.0  1.006667e+09
# 1966  10148841.0  1.400000e+09
# 1967  10368600.0  1.673333e+09
# 1968  10599790.0  1.373333e+09
# 1969  10849510.0  1.408889e+09
# 1970  11121097.0  1.748887e+09
# 1971  11412821.0  1.831109e+09
# 1972  11716896.0  1.595555e+09
# 1973  12022514.0  1.733333e+09
# 1974  12315553.0  2.155555e+09
# 1975  12582954.0  2.366667e+09
# 1976  12831361.0  2.555556e+09
# 1977  13056499.0  2.953333e+09
# 1978  13222547.0  3.300000e+09
# 1979  13283279.0  3.697940e+09
# 1980  13211412.0  3.641723e+09
# 1981  12996923.0  3.478788e+09
# 2001  20531160.0  2.461666e+09
# 2002  21487079.0  4.128818e+09
# 2003  22507368.0  4.583649e+09
# 2004  23499850.0  5.285462e+09
# 2005  24399948.0  6.275076e+09
# 2006  25183615.0  7.057598e+09
# ...
